# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1=pd.read_excel('Telco-Customer-Churn.xlsx')

# %%
data1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # 1) Compare churn count with respect to gender.

# %%
data=data1[data1['Churn']=='Yes']
sns.countplot(x=data['Churn'],data=data1,hue='gender')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# # 3) Compare 'tenure' with 'Total Charges'

# %%
sns.scatterplot(x='tenure',y='TotalCharges',data=data1)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# # 2) Find out how many female senior citizens there in the dataset

# %%
data2=data1[(data1['SeniorCitizen']==1) & (data1['gender']=='Female')]
data2['SeniorCitizen'].value_counts()
# Out:
# 1    568
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# # 4) Find out which contract preffered by the senior citizen

# %%
sns.countplot(x=data1[data1['SeniorCitizen']==1]['Contract'])
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %% [markdown]
# # Comment on your findings on Payment Method?

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=data1['PaymentMethod'])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
